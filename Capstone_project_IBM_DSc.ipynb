# %% [markdown]
# # A JAPANESE IN BARCELONA

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# Barcelona is one of the cities in the world with more cosmopolitanism in Europe. Barcelona has one of the largest catering offers per square metre in Europe
#
# Not all restaurants are the same, they do not offer the same service. This makes it sometimes difficult to discern which neighborhoods are the most suitable for our needs.
#
# in this project we will analyze which is the best district of barcelona to find a Japanese restaurant and where can be found

# %% [markdown]
# ## 2. Data and Source

# %% [markdown]
# For the purpose of this study, we will use  data provided by **Open Data BCN** ( https://opendata-ajuntament.barcelona.cat)

# %% [markdown]
# The file used on that project is  **EQUIPAMENTS_RESTAURANTS_restaurants.csv** . A dataset from the Barcelona Local government in order to classify leissure equipment in the city.
#
#  Additionally we will use foursquare APi in order to locate several options on a map.

# %% [markdown]
# ## 3. Methodology

# %% [markdown]
# In order to elaborate this project we will carry out several steps :
#
# * convert the data fom **Open BCN** into a more manageable dataframe.
# * Eliminate the duplicates to avoid deviations in the results.
# * Generate  proper querys to Foursquare in order to relate with BCN dataset
# * Design and apply an algorithm for choosing the most adecuat.

# %% [markdown]
# ## 4. Results

# %%
# First of all we import needed libraries for the project
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import json ,requests


# Define Url where to reach dataset
url  = 'https://opendata-ajuntament.barcelona.cat/data/dataset/b4d2cc2f-67dc-481a-a7cb-1999fd0d5740/resource/f4f2abbf-09e8-42a4-9648-c26ec5e0f3be/download'

# as dataset is in ".csv" format,then we use Panda's read_csv  for reading the data.
data_csv= pd.read_csv(url)

# %%
# Then, we convert de data received into a dataframe with pandas
data_df=pd.DataFrame(data_csv)
# Eliminate duplicate registries.
df = data_df.drop_duplicates(['CODI_EQUIPAMENT'])
#df.head() #Enable if you want to check the dataset on that point

# %%
url = 'https://api.foursquare.com/v2/venues/explore'

params = dict(
client_id='X05YNJIZO4FRI42P2MNDWQOUMIAZJV4Z0SWA4LZQGKOKBGA4',
client_secret='KDR1IOSQ2J5KVHVTVWIBXRWBKB5ZJILPGV5NJI03NZCRSQI0',
v='20180323',
#ll='40.7243,-74.0018',
near= 'barcelona',
query='japanese',
limit=50
)
resp = requests.get(url=url, params=params).json()

# %%
resp2= json.loads(['response'])
data_df=pd.DataFrame(resp2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-e943ffe79b83> in <module>()
# ----> 1 resp2= json.loads(['response'])
#       2 data_df=pd.DataFrame(resp2)
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     339     else:
#     340         if not isinstance(s, (bytes, bytearray)):
# --> 341             raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     342                             f'not {s.__class__.__name__}')
#     343         s = s.decode(detect_encoding(s), 'surrogatepass')
#
# TypeError: the JSON object must be str, bytes or bytearray, not list

# %%
data_df
# Out:
#                                                meta  \
# code                                            200
# geocode                                         NaN
# groups                                          NaN
# headerFullLocation                              NaN
# headerLocation                                  NaN
# headerLocationGranularity                       NaN
# query                                           NaN
# requestId                  5ecb7206df2774001b28501d
# suggestedBounds                                 NaN
# suggestedFilters                                NaN
# totalResults                                    NaN
#
#                                                                     response
# code                                                                     NaN
# geocode                    {'what': '', 'where': 'barcelona', 'center': {...
# groups                     [{'type': 'Recommended Places', 'name': 'recom...
# ...

# %%
print(data_df[['geocode']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-e6f204653c02> in <module>()
# ----> 1 print(data_df[['geocode']])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ...

# %%
resp
# Out:
# {'meta': {'code': 200, 'requestId': '5ecb7206df2774001b28501d'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'geocode': {'what': '',
#    'where': 'barcelona',
#    'center': {'lat': 41.38879, 'lng': 2.15899},
#    'displayString': 'Barcelona, Catalonia, Spain',
#    'cc': 'ES',
#    'geometry': {'bounds': {'ne': {'lat': 41.46973191488868,
#       'lng': 2.2386972615027014},
#      'sw': {'lat': 41.27634481709274, 'lng': 2.053937015602322}}},
#    'slug': 'barcelona-spain',
#    'longId': '72057594041056696'},
#   'headerLocation': 'Barcelona',
#   'headerFullLocation': 'Barcelona',
#   'headerLocationGranularity': 'city',
#   'query': 'japanese',
#   'totalResults': 180,
#   'suggestedBounds': {'ne': {'lat': 41.41042266424379,
#     'lng': 2.2003417376562218},
#    'sw': {'lat': 41.362911196909245, 'lng': 2.1274504013265507}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
# ...

# %% [markdown]
# ## 5. Discussion

# %% [markdown]
# ## 6. Conclusion
